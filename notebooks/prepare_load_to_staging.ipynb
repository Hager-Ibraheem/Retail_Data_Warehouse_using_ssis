# %%
import pandas as pd
sales_df = pd.read_csv("../data/raw/sales.csv")
sales_df
# Out:
#      TransactionID        Date  ProductCategory  \
# 0            10001  2024-01-01      Electronics
# 1            10002  2024-01-02  Home Appliances
# 2            10003  2024-01-03         Clothing
# 3            10004  2024-01-04            Books
# 4            10005  2024-01-05  Beauty Products
# ..             ...         ...              ...
# 235          10236  2024-08-23  Home Appliances
# 236          10237  2024-08-24         Clothing
# 237          10238  2024-08-25            Books
# 238          10239  2024-08-26  Beauty Products
# 239          10240  2024-08-27           Sports
#
#                                          ProductName  UnitsSold  UnitPrice  \
# 0                                      iPhone 14 Pro          2     999.99
# 1                                   Dyson V11 Vacuum          1     499.99
# 2                                   Levi's 501 Jeans          3      69.99
# 3                                  The Da Vinci Code          4      15.99
# ...

# %%
sales_df["ProductName"].nunique()
# Out:
# 232

# %%
duplicated_rows = sales_df[sales_df.duplicated(subset='ProductName', keep=False)].sort_values(by='ProductName')
duplicated_rows
# Out:
#      TransactionID        Date  ProductCategory  \
# 9            10010  2024-01-10            Books
# 231          10232  2024-08-19            Books
# 16           10017  2024-01-17  Beauty Products
# 127          10128  2024-05-07  Home Appliances
# 18           10019  2024-01-19      Electronics
# 221          10222  2024-08-09           Sports
# 13           10014  2024-01-14  Home Appliances
# 211          10212  2024-07-30  Home Appliances
# 30           10031  2024-01-31      Electronics
# 150          10151  2024-05-30      Electronics
# 87           10088  2024-03-28            Books
# 189          10190  2024-07-08            Books
# 171          10172  2024-06-20            Books
# 213          10214  2024-08-01            Books
# 51           10052  2024-02-21            Books
# 225          10226  2024-08-13            Books
#
#                                           ProductName  UnitsSold  UnitPrice  \
# ...

# %% [markdown]
# From the result of duplicated_rows,
# there are 6 products have changes in the product category or price

# %%
customer_df = pd.read_csv("../data/raw/customers.csv")
customer_name = list(customer_df['first_name'] +" "+ customer_df['last_name']) # will be added in the sales data

# %%
customer_df.to_csv("../data/staging/customers.csv", index=False)

# %%
store_df = pd.read_csv("../data/raw/stores.csv")
store_name = list(store_df['store_name']) # will be added in the sales data

# %%
store_df.to_csv("../data/staging/stores.csv", index=False)

# %%
import random
random.seed(42)

def sales_update(sales_df,store_n,customer_n):
    sales_df['customer_name'] = [random.choice(customer_n) for i in range(len(sales_df))]
    sales_df['store_name'] = [random.choice(store_n) for i in range(len(sales_df))]
    return sales_df

sales_final = sales_update(sales_df,store_name,customer_name)
sales_final.to_csv("../data/staging/sales_final.csv", index=False)
